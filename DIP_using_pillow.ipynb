# %% [markdown]
# <a href="https://colab.research.google.com/github/Tehzeeb-hassan/Machine-Learning/blob/main/DIP_using_pillow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
valley=np.array(Image.open('/content/images.jpeg'))
plt.figure(figsize=(4,4))
plt.imshow(valley)
plt.show()

# %%
left = 70
right = 110
crop_horizontal = crop_top[: ,left:right,:]
plt.figure(figsize=(5,5))
plt.imshow(crop_horizontal)
plt.show()

# %%
gb=valley

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(gb)
plt.title("Gilgit-Baltistan")
plt.subplot(122)
plt.imshow(valley)
plt.title("valley")
plt.show()

# %%
array = np.array(valley)
width, height, C = array.shape
print('width', width ,'height and Channel', height, C)
array
# Out:
# width 225 height and Channel 225 3
# array([[[241, 231, 232],
#         [241, 231, 232],
#         [241, 231, 232],
#         ...,
#         [165, 187, 200],
#         [165, 187, 200],
#         [163, 188, 195]],
#
#        [[243, 233, 234],
#         [243, 233, 234],
#         [243, 233, 234],
#         ...,
#         [164, 186, 199],
#         [164, 186, 199],
#         [158, 183, 190]],
#
#        [[245, 235, 236],
#         [245, 235, 236],
#         [245, 235, 236],
#         ...,
#         [163, 185, 198],
#         [163, 185, 198],
#         [163, 188, 195]],
#
#        ...,
#
#        [[171, 191, 142],
#         [159, 179, 130],
#         [176, 195, 149],
#         ...,
#         [133, 151, 113],
#         [ 98, 123,  40],
#         [176, 185, 164]],
#
#        [[170, 190, 139],
#         [135, 155, 106],
#         [170, 190, 141],
#         ...,
#         [125, 142, 106],
#         [106, 131,  47],
#         [170, 180, 156]],
#
#        [[122, 147, 107],
# ...

# %%
from PIL import ImageOps

# %%
array_flip = np.zeros((width, height, C), dtype=np.uint8)

# %%
for i,row in enumerate(array):
    array_flip[width - 1 - i, :, :] = row

# %%
for i,row in enumerate(array):
    array_flip[width - 1 - i, :, :] = row

# %%
plt.imshow(array_flip)

# %%
left = 50
right = 100
crop_top = array[upper: lower,:,:]
plt.figure(figsize=(5,5))
plt.imshow(crop_top)
plt.show()

# %%
left = 70
right = 110
crop_horizontal = crop_top[: ,left:right,:]
plt.figure(figsize=(5,5))
plt.imshow(crop_horizontal)
plt.show()

# %%
import cv2
image = cv2.imread('//content/images.jpeg')
plt.imshow(image)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image)
cv2.imwrite('gray_image.jpg', gray_image)
edges = cv2.Canny(gray_image, 100, 200)
plt.imshow(edges)
